# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/datawarehouse-seguros/blob/main/Aseguradoras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 16.4 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
database_url = "postgresql://etl_aseguradoras_xhzk_user:oi5ecQdH2xADCoNDerEt0PVODnKVAFS0@dpg-d6u5b4euk2gs7396o210-a.oregon-postgres.render.com/etl_aseguradoras_xhzk"

# %%
engine = create_engine("postgresql://etl_aseguradoras_xhzk_user:oi5ecQdH2xADCoNDerEt0PVODnKVAFS0@dpg-d6u5b4euk2gs7396o210-a.oregon-postgres.render.com/etl_aseguradoras_xhzk")

# %%
test = pd.read_sql("SELECT 1", engine)

# %%
print(test)
# Out:
#    ?column?
# 0         1

# %%
url = "https://raw.githubusercontent.com/heydi98-hl/etl-data-pipeline/refs/heads/main/aseguradoras.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   id_tipo_seguro;tipo;categoria;riesgo_base
# 0                         1;Pyme;Familiar;-
# 1           2;Industrial;Empresarial; 4.68
# 2                3;Industrial;Familiar;5.10
# 3                 4;Industrial;Personal;N/A
# 4                  5;Auto;empresarial ;9.07

# %%
df.shape
# Out:
# (12, 1)

# %%
df.columns
# Out:
# Index(['id_tipo_seguro;tipo;categoria;riesgo_base'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 1 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   id_tipo_seguro;tipo;categoria;riesgo_base  12 non-null     object
# dtypes: object(1)
# memory usage: 228.0+ bytes

# %%
df.isnull().sum()
# Out:
# id_tipo_seguro;tipo;categoria;riesgo_base    0
# dtype: int64

# %%
clientes = df.copy()

# %%
clientes.columns = clientes.columns.str.strip().str.lower()

# %%
for col in clientes.select_dtypes(include='object').columns:

    clientes[col] = clientes[col].astype(str).str.strip()

# %%
clientes = clientes.replace(r'^\s*$', pd.NA, regex=True)

# %%
clientes = clientes.drop_duplicates()

# %%
def motivo(row):
    motivos = []

# %%
# !pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine
import pandas as pd

database_url = "postgresql://etl_aseguradoras_xhzk_user:oi5ecQdH2xADCoNDerEt0PVODnKVAFS0@dpg-d6u5b4euk2gs7396o210-a.oregon-postgres.render.com/etl_aseguradoras_xhzk"

engine = create_engine(database_url)

test = pd.read_sql("SELECT 1", engine)

print(test)
# Out:
# ...
#    ?column?
# 0         1
